# %% [markdown]
# # Smartphone Kimovil Review Vocabulary and Linked Data
# ## Kontributor: Imam Mansyur Solichin, Bayu Narendra Jati, Nur Aini Rakhmawati, S.Kom., M.Sc.Eng., Ph.D
# ## email kontributor: bayunarendrajati@gmail.com , imammansyursolichin@gmail.com
# ## Departemen Sistem Informasi, Institut Teknologi Sepuluh Nopember
# Abstrak:
# Berikut adalah extended vocabulary dengan menggunakan dataset smartphone review dari website kimovil. Kami memulai pengerjaan dengan membuat vocabulary sendiri. Setelah model telah ditentukan, kami menggantinya dengan vocabulary yang telah umum digunakan. Selanjutnya, kami menyambungkan vocabulary ke dataset lain (linked data). Dalam pengerjaannya, kami mereferensi vocabulary dari schema.org dan juga cookingbigdata.com/linkeddata/ccinstances.

# %% [markdown]
# ## Dataset
#
# Dataset ini menunjukkan spesifikasi handphone serta penilaiannya berdasarkan website Kimovil. Dataset ini dapat diakses dari https://www.kaggle.com/linxzy/smartphone-price-compared-by-kimovil-review
#
# Tabel dataset

# %%
#load CSV dengan pandas
#display the table 

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0c301508-f1ec-43b1-b1c1-6a1c39491d81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c301508-f1ec-43b1-b1c1-6a1c39491d81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Smartphone(1jt-2jt).csv to Smartphone(1jt-2jt).csv

# %%
uploaded = {'Smartphone(1jt-2jt).csv': b'Name;Brand;Price;Processor;RAM;Memory;Screen;Performance;Camera;Connectivity;Battery;Link\r\nAlcatel 1S;Alcatel;1.599.000;Mediatek;3;32;4.1;5.7;4.8;5.5;5.9;https://www.tokopedia.com/mygadgetholic/alcatel-1s-5028y-smartphone-3-32gb-garansi-resmi-green\r\nAlcatel 1SE;Alcatel;1.599.000;Unisoc;4;64;3.6;5.4;4.9;5.4;5.7;https://www.tokopedia.com/mygadgetholic/alcatel-1se-5030u-smartphone-4-64gb-garansi-resmi-green\r\nZenfone 4 Max;Asus;1.699.000;Snapdragon;3;32;4.1;4.5;3.7;5.7;7.7;https://www.tokopedia.com/mygadgetholic/asus-zenfone-4-max-zc554kl-smartphone-ram-3gb-rom-32gb-gold\r\nInfinix Hot 10 Play;Infinix;1.259.000;Mediatek;2;32;4.3;5.7;4.6;6.7;8.8;https://www.tokopedia.com/mygadgetholic/infinix-hot-10-play-x688c-smartphone-2gb-32gb-garansi-resmi-morandi-green\r\nNokia C3;Nokia;1.499.000;Unisoc;2;16;3.7;4.3;3.5;3.5;4.4;https://www.tokopedia.com/nokia-mobile/nokia-c3-2-16gb-nordic-blue\r\nOppo A11;Oppo;1.399.000;Mediatek;2;32;3.9;5.4;4.5;4.5;6.8;https://www.tokopedia.com/oppo/oppo-a11k-smartphone-2gb-32gb-garansi-resmi-biru\r\nOppo A15;Oppo;1.799.000;Mediatek;3;32;6.4;5.9;4.7;5.9;6.9;https://www.tokopedia.com/pvblicone/smartphone-oppo-a15-ram-3gb-internal-32gb-garansi-resmi-indonesia-hitam\r\nOppo A11K;Oppo;1.699.000;Mediatek;2;32;3.9;5.4;4.5;4.5;6.8;https://www.tokopedia.com/supergadgettt/oppo-a11k-2-32-gb-galaxy-smartphone-ram-2gb-rom-32gb-murah-resmi-black\r\nPoco M3;Poco;1.799.000;Snapdragon;4;64;7.0;6.7;6.8;7.0;8.9;https://www.tokopedia.com/xiaomi/xiaomi-official-poco-m3-4-64gb-snapdragon-662-mi-smartphone-power-black\r\nRealme C20;Realme;1.249.000;Mediatek;2;32;5.8;5.8;3.4;5.6;8.1;https://www.tokopedia.com/mygadgetholic/realme-c20-smartphone-ram-2gb-rom-32gb-garansi-resmi-iron-grey\r\nRealme C11;Realme;1.429.000;Mediatek;2;32;6.3;5.8;4.4;5.1;7.9;https://www.tokopedia.com/mygadgetholic/realme-c11-smartphone-2-32gb-garansi-resmi-realme-green\r\nRealme C21;Realme ;1.700.000;Mediatek;3;32;5.1;5.9;4.7;5.3;8.1;https://www.tokopedia.com/wijaya/realme-c21-smartphone-3-32gb-garansi-resmi\r\nSamsung Galaxy A02s;Samsung;1.999.000;Snapdragon;4;64;3.6;5.4;5.0;5.2;7.9;https://www.tokopedia.com/global-teleshop/samsung-galaxy-a02s-smartphone-4-64gb-garansi-resmi-blue\r\nSamsung Galaxy A10s;Samsung;1.335.000;Mediatek;2;32;3.6;5.2;4.8;5.0;5.8;https://www.kimovil.com/en/where-to-buy-samsung-galaxy-a10s\r\nSamsung Galaxy A11;Samsung;1.456.000;Snapdragon;3;32;3.6;5.3;5.1;4.8;6.2;https://www.tokopedia.com/prismaroxy/samsung-galaxy-a11-3-32gb-smartphone-garansi-resmi-putih\r\nSamsung Galaxy M11;Samsung;1.495.000;Snapdragon;3;32;3.2;5.4;5.1;5.7;7.9;https://www.tokopedia.com/prismaroxy/samsung-galaxy-m11-3-32gb-smartphone-garansi-resmi-sein-hitam\r\nSamsung Galaxy J7;Samsung;1.999.000;Exynos;2;16;4.0;4.7;4.3;5.9;5.5;https://www.tokopedia.com/mygadgetholic/samsung-galaxy-j7-j710-smartphone-2gb-16gb-rom-hitam\r\nSharp Aquos V SH-C02;Sharp;1.874.000;Snapdragon;4;64;6.7;6.2;5.5;5.8;4.8;https://www.tokopedia.com/didik-electronic/promo-sharp-aquos-v-sh-c02-shc02-smartphone-64gb-ram-4gb-murah\r\nVivo Y20;Vivo;1.900.000;Snapdragon;3;64;3.6;6.3;4.8;5.2;8.2;https://www.tokopedia.com/supergadgettt/vivo-y20-smartphone-3gb-64gb-garansi-resmi-dawn-white\r\nVivo Y12S;Vivo;1.899.000;Snapdragon;2;32;3.6;5.7;4.5;5.5;7.9;https://www.tokopedia.com/prismaroxy/vivo-y1s-2-32gb-smartphone\r\nVivo Y91C;Vivo;1.599.000;Mediatek;2;32;5.6;5.1;3.8;4.0;5.9;https://www.tokopedia.com/andalascellularb/vivo-smartphone-y91c-2-32gb-6-2-inch-garansi-resmi-hitam\r\nRedmi 9A;Xiaomi;1.209.000;Mediatek;2;32;6.5;6.3;6.0;7.6;8.9;https://www.tokopedia.com/global-teleshop/xiaomi-redmi-9a-smartphone-2-32gb-gray\r\nRedmi 9C;Xiaomi;1.550.000;Mediatek;3;32;4.5;5.8;4.7;6.1;7.8;https://www.tokopedia.com/wijaya/xiaomi-redmi-9c-smartphone-3-32gb-garansi-resmi-tam\r\nRedmi 9T;Xiaomi;2.000.000;Snapdragon;4;64;7.0;6.6;7.1;7.5;8.9;https://www.tokopedia.com/wijaya/xiaomi-redmi-9t-smartphone-4-64gb-garansi-resmi\r\n'}

# %%
import io, pandas as pd
data_raw = pd.read_csv(io.BytesIO(uploaded['Smartphone(1jt-2jt).csv']), delimiter=";")
data_raw
# Out:
#                     Name  ...                                               Link
# 0             Alcatel 1S  ...  https://www.tokopedia.com/mygadgetholic/alcate...
# 1            Alcatel 1SE  ...  https://www.tokopedia.com/mygadgetholic/alcate...
# 2          Zenfone 4 Max  ...  https://www.tokopedia.com/mygadgetholic/asus-z...
# 3    Infinix Hot 10 Play  ...  https://www.tokopedia.com/mygadgetholic/infini...
# 4               Nokia C3  ...  https://www.tokopedia.com/nokia-mobile/nokia-c...
# 5               Oppo A11  ...  https://www.tokopedia.com/oppo/oppo-a11k-smart...
# 6               Oppo A15  ...  https://www.tokopedia.com/pvblicone/smartphone...
# 7              Oppo A11K  ...  https://www.tokopedia.com/supergadgettt/oppo-a...
# 8                Poco M3  ...  https://www.tokopedia.com/xiaomi/xiaomi-offici...
# 9             Realme C20  ...  https://www.tokopedia.com/mygadgetholic/realme...
# 10            Realme C11  ...  https://www.tokopedia.com/mygadgetholic/realme...
# ...

# %% [markdown]
# # Vocabulary
#
# ## Namespace
# ex: <https://example.org/>.
#
# rdfs:<http://www.w3.org/2000/01/rdf-schema#>.
#
# rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
#
# xsd: <http://www.w3.org/2001/XMLSchema#>.
#
# ## Kelas smartphone
#
# Properti : produsen, seharga, memilikiRAM, memilikiMemori, memilikiProcessor, url, memilikiReview.
#
# ## Kelas brand
#
# Properti : namaBrand
#
# ## Kelas review
#
# Property : screen-review, performance-review, connectivity-review, camera-review, battery-review

# %%
pip install --no-input jupyter-rdfify
# Out:
# ...
#      |████████████████████████████████| 51 kB 508 kB/s
# ...
#      |████████████████████████████████| 788 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 379 kB 57.6 MB/s
# ...
#      |████████████████████████████████| 370 kB 56.5 MB/s
# ...
#      |████████████████████████████████| 45 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 69 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 231 kB 50.8 MB/s
# ...
#      |████████████████████████████████| 80 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 117 kB 59.3 MB/s
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.2-py3-none-any.whl size=144567 sha256=a9a477b4003e8b89281b91c097676d8c15ea7481005564f5329d94a86553300d
#   Stored in directory: /root/.cache/pip/wheels/14/4c/18/1dbbc9875a2547d2063400ea9f404da4af3331965a71061029
# ...

# %%
# %reload_ext jupyter-rdfify
# Out:
# /usr/local/lib/python3.7/dist-packages/rdflib_jsonld/__init__.py:12: DeprecationWarning: The rdflib-jsonld package has been integrated into rdflib as of rdflib==6.0.1.  Please remove rdflib-jsonld from your project's dependencies.
#   DeprecationWarning,

# %%
# %%rdf turtle --label Redmi-9A
#
# #Namespace
# @prefix ex: <https://example.org/>.
# @prefix rdfs:<http://www.w3.org/2000/01/rdf-schema#>.
# @prefix rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
#
# #Class
# ex:smartphone a rdfs:Class.
# ex:brand a rdfs:Class.
# ex:review a rdfs:Class.
#
# #Property
# ex:produsen a rdf:property.
# ex:produsen rdfs:domain ex:smartphone.
# ex:produsen rdfs:range ex:brand.
#
# ex:namaBrand a rdf:property.
# ex:namaBrand rdfs:domain ex:brand.
# ex:namaBrand rdfs:range xsd:string.
#
# ex:seharga a rdf:property.
# ex:seharga rdfs:domain ex:smartphone.
# ex:seharga rdfs:range xsd:currency.
#
# ex:memilikiRam a rdf:property.
# ex:memilikiRam rdfs:domain ex:smartphone.
# ex:memilikiRam rdfs:range ex:gigabyte.
#
# ex:memilikiMemory a rdf:property.
# ex:memilikiMemory rdfs:domain ex:smartphone.
# ex:memilikiMemory rdfs:range ex:gigabyte.
#
# ex:memilikiProcessor a rdf:property.
# ex:memilikiProcessor rdfs:domain ex:smartphone.
# ex:memilikiProcessor rdfs:range ex:brand.
#
# ex:url a rdf:property.
# ex:url rdfs:domain ex:smartphone.
# ex:url rdfs:range xsd:string.
#
# ex:memilikiReview a rdf:property.
# ex:memilikiReview rdfs:domain ex:smartphone.
# ex:memilikiReview rdfs:range ex:review.
#
# ex:screen-review a rdf:property.
# ex:screen-review rdfs:domain ex:review.
# ex:screen-review rdfs:range xsd:float.
#
# ex:performance-review a rdf:property.
# ex:performance-review rdfs:domain ex:review.
# ex:performance-review rdfs:range xsd:float.
#
# ex:connectivity-review a rdf:property.
# ex:connectivity-review rdfs:domain ex:review.
# ex:connectivity-review rdfs:range xsd:float.
#
# ex:camera-review a rdf:property.
# ex:camera-review rdfs:domain ex:review.
# ex:camera-review rdfs:range xsd:float.
#
# ex:battery-review a rdf:property.
# ex:battery-review rdfs:domain ex:review.
# ex:battery-review rdfs:range xsd:float.
#
# #Instance
# ex:xiaomi a ex:brand.
# ex:xiaomi ex:namaBrand "Xiaomi"^^xsd:string.
# ex:kireview a ex:review.
# ex:mediatek a ex:brand.
# ex:mediatek ex:namaBrand "Mediatek"^^xsd:string.
# ex:redmi9a a ex:smartphone.
# ex:redmi9a ex:produsen ex:xiaomi.
# ex:redmi9a ex:seharga "1209000"^^xsd:currency.
# ex:redmi9a ex:memilikiRam "2"^^ex:gigabyte.
# ex:redmi9a ex:memilikiMemory "32"^^ex:gigabyte.
# ex:redmi9a ex:memilikiProcessor ex:mediatek.
# ex:redmi9a ex:url "https://www.tokopedia.com/global-teleshop/xiaomi-redmi-9a-smartphone-2-32gb-gray"^^xsd:string.
# ex:redmi9a ex:memilikiReview ex:kireview.
# ex:kireview ex:screen-review "6.5"^^xsd:float.
# ex:kireview ex:performance-review "6.3"^^xsd:float.
# ex:kireview ex:connectivity-review "7.6"^^xsd:float.
# ex:kireview ex:camera-review "6.0"^^xsd:float.
# ex:kireview ex:screen-review "8.9"^^xsd:float.

# %% [markdown]
# # Vocabulary Perpanjangan dari Vocabulary Populer
#
# Vocabulary ini telah ditambahkan linked data
#
# ## Namespace
# ex: <https://example.org/>.
#
# rdfs:<http://www.w3.org/2000/01/rdf-schema#>.
#
# rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
#
# xsd: <http://www.w3.org/2001/XMLSchema#>.
#
# schema: <http://schema.org/>.
#
# cci: <http://cookingbigdata.com/linkeddata/ccinstances/>.
#
# ## Kelas Product
#
# Properti :  offers, aggregateRating, url, brand
#
# ## Kelas Brand
#
# Properti : name
#
# ## Kelas Offer
#
# Properti : price, priceCurrency
#
# ## Kelas AggregateRating
#
# Properti : ratingValue
#
# ## Kelas Instance
#
# Properti : hasRAM, hasStorage, hasCPU
#
# ## Kelas ram
#
# Properti : ram_size
#
# ## Kelas storage
#
# Properti : storage_size
#
# ## Kelas cpu :
#
# Properti : cpu_model

# %%
# %%rdf turtle --label Redmi-9A
#
# #Namespace
# @prefix ex: <https://example.org/>.
# @prefix rdfs:<http://www.w3.org/2000/01/rdf-schema#>.
# @prefix rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
# @prefix schema: <http://schema.org/>.
# @prefix cci: <http://cookingbigdata.com/linkeddata/ccinstances/>.
# @prefix dbr: <http://dbpedia.org/resource/>.
#
# #Class
#
# #Property
#
# #Instance
# ex:xiaomi a schema:Brand.
# ex:xiaomi schema:name "Xiaomi"^^schema:Text.
# ex:redmi9a a schema:Product, cci:Instance.
# ex:redmi9a schema:brand ex:xiaomi.
#
# ex:hargaTokopedia a schema:Offer.
# ex:redmi9a schema:offers ex:hargaTokopedia.
# ex:hargaTokopedia schema:price "1209000"^^schema:Number.
# ex:hargaTokopedia schema:priceCurrency "IDR"^^schema:Text.
#
# ex:device_ram a cci:ram.
# ex:redmi9a cci:hasRAM ex:device_ram.
# ex:device_ram cci:ram_size "2"^^xsd:integer.
#
# ex:device_storage a cci:storage.
# ex:redmi9a cci:hasStorage ex:device_storage.
# ex:device_storage cci:storage_size "32"^^xsd:integer.
#
# ex:mediatek a cci:cpu.
# ex:redmi9a cci:hasCPU ex:mediatek.
# ex:mediatek cci:cpu_model "Mediatek"^^xsd:string.
#
# ex:redmi9a schema:url "https://www.tokopedia.com/global-teleshop/xiaomi-redmi-9a-smartphone-2-32gb-gray"^^schema:URL.
#
# ex:screen_rating a schema:AggregateRating.
# ex:redmi9a schema:aggregateRating ex:screen_rating.
# ex:screen_rating schema:ratingValue "6.5"^^schema:Number.
#
# ex:performance_rating a schema:AggregateRating.
# ex:redmi9a schema:aggregateRating ex:performance_rating.
# ex:performance_rating schema:ratingValue "6.3"^^schema:Number.
#
# ex:connectivity_rating a schema:AggregateRating.
# ex:redmi9a schema:aggregateRating ex:connectivity_rating.
# ex:connectivity_rating schema:ratingValue "7.6"^^schema:Number.
#
# ex:camera_rating a schema:AggregateRating.
# ex:redmi9a schema:aggregateRating ex:camera_rating.
# ex:camera_rating schema:ratingValue "6.0"^^schema:Number.
#
# ex:battery_rating a schema:AggregateRating.
# ex:redmi9a schema:aggregateRating ex:battery_rating.
# ex:battery_rating schema:ratingValue "8.9"^^schema:Number.
#
# #Linked data
# ex:xiaomi rdfs:seeAlso dbr:Lei_Jun.

# %%
# %%rdf turtle --label Redmi-9C
#
# #Namespace
# @prefix ex: <https://example.org/>.
# @prefix rdfs:<http://www.w3.org/2000/01/rdf-schema#>.
# @prefix rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
# @prefix schema: <http://schema.org/>.
# @prefix cci: <http://cookingbigdata.com/linkeddata/ccinstances/>.
# @prefix dbr: <http://dbpedia.org/resource/>.
#
# #Class
#
# #Property
#
#
# #Instance
# ex:xiaomi a schema:Brand.
# ex:xiaomi schema:name "Xiaomi"^^schema:Text.
# ex:redmi9c a schema:Product, cci:Instance.
# ex:redmi9c schema:brand ex:xiaomi.
#
# ex:hargaTokopedia a schema:Offer.
# ex:redmi9c schema:offers ex:hargaTokopedia.
# ex:hargaTokopedia schema:price "1550000"^^schema:Number.
# ex:hargaTokopedia schema:priceCurrency "IDR"^^schema:Text.
#
# ex:device_ram a cci:ram.
# ex:redmi9c cci:hasRAM ex:device_ram.
# ex:device_ram cci:ram_size "3"^^xsd:integer.
#
# ex:device_storage a cci:storage.
# ex:redmi9c cci:hasStorage ex:device_storage.
# ex:device_storage cci:storage_size "32"^^xsd:integer.
#
# ex:mediatek a cci:cpu.
# ex:redmi9c cci:hasCPU ex:mediatek.
# ex:mediatek cci:cpu_model "Mediatek"^^xsd:string.
#
# ex:redmi9c schema:url "https://www.tokopedia.com/wijaya/xiaomi-redmi-9c-smartphone-3-32gb-garansi-resmi-tam"^^schema:URL.
#
# ex:screen_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:screen_rating.
# ex:screen_rating schema:ratingValue "4.5"^^schema:Number.
#
# ex:performance_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:performance_rating.
# ex:performance_rating schema:ratingValue "5.8"^^schema:Number.
#
# ex:connectivity_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:connectivity_rating.
# ex:connectivity_rating schema:ratingValue "6.1"^^schema:Number.
#
# ex:camera_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:camera_rating.
# ex:camera_rating schema:ratingValue "4.7"^^schema:Number.
#
# ex:battery_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:battery_rating.
# ex:battery_rating schema:ratingValue "7.8"^^schema:Number.
#
# #Linked data
# ex:xiaomi rdfs:seeAlso dbr:Lei_Jun.

# %%
# %%rdf turtle --label Redmi-9T
#
# #Namespace
# @prefix ex: <https://example.org/>.
# @prefix rdfs:<http://www.w3.org/2000/01/rdf-schema#>.
# @prefix rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
# @prefix schema: <http://schema.org/>.
# @prefix cci: <http://cookingbigdata.com/linkeddata/ccinstances/>.
# @prefix dbr: <http://dbpedia.org/resource/>.
#
# #Class
#
# #Property
#
#
# #Instance
# ex:xiaomi a schema:Brand.
# ex:xiaomi schema:name "Xiaomi"^^schema:Text.
# ex:redmi9c a schema:Product, cci:Instance.
# ex:redmi9c schema:brand ex:xiaomi.
#
# ex:hargaTokopedia a schema:Offer.
# ex:redmi9c schema:offers ex:hargaTokopedia.
# ex:hargaTokopedia schema:price "2000000"^^schema:Number.
# ex:hargaTokopedia schema:priceCurrency "IDR"^^schema:Text.
#
# ex:device_ram a cci:ram.
# ex:redmi9c cci:hasRAM ex:device_ram.
# ex:device_ram cci:ram_size "4"^^xsd:integer.
#
# ex:device_storage a cci:storage.
# ex:redmi9c cci:hasStorage ex:device_storage.
# ex:device_storage cci:storage_size "64"^^xsd:integer.
#
# ex:mediatek a cci:cpu.
# ex:redmi9c cci:hasCPU ex:mediatek.
# ex:mediatek cci:cpu_model "Snapdragon"^^xsd:string.
#
# ex:redmi9c schema:url "https://www.tokopedia.com/wijaya/xiaomi-redmi-9t-smartphone-4-64gb-garansi-resmi"^^schema:URL.
#
# ex:screen_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:screen_rating.
# ex:screen_rating schema:ratingValue "7.0"^^schema:Number.
#
# ex:performance_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:performance_rating.
# ex:performance_rating schema:ratingValue "6.6"^^schema:Number.
#
# ex:connectivity_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:connectivity_rating.
# ex:connectivity_rating schema:ratingValue "7.5"^^schema:Number.
#
# ex:camera_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:camera_rating.
# ex:camera_rating schema:ratingValue "7.1"^^schema:Number.
#
# ex:battery_rating a schema:AggregateRating.
# ex:redmi9c schema:aggregateRating ex:battery_rating.
# ex:battery_rating schema:ratingValue "8.9"^^schema:Number.
#
# #Linked data
# ex:xiaomi rdfs:seeAlso dbr:Lei_Jun.

# %% [markdown]
# ##Daftar Pustaka:
#
# 1.   Rakhmawati, N. A. (2015). Semantic Web dan Linked Data. Yogyakarta, Indonesia: SiBuku.
# 2.   DOI: 10.5281/zenodo.5521338
# 3.   Imam Mansyur Solichin, Bayu Narendra Jati, and Nur Aini Rakhmawati. "Smartphone Kimovil Review Vocabulary" http://dx.doi.org/10.13140/RG.2.2.26684.97923
